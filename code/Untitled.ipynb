# %%
import rosbag
import rosbag_pandas 
import pandas as pd

df = rosbag_pandas.bag_to_dataframe("./op3_bag/2019-03-20-14-43-07.bag")

# %%
df['robotis/goal_joint_states/position/15'].describe()
# Out:
# count    11350.000000
# mean         0.009699
# std          0.191641
# min         -0.230289
# 25%         -0.199197
# 50%          0.000000
# 75%          0.181903
# max          0.307267
# Name: robotis/goal_joint_states/position/15, dtype: float64

# %%
df['robotis/goal_joint_states/position/15'].plot()

# %%
df.filter(regex='goal_joint_states/position', axis=1).plot(legend=False, figsize=(15, 10))

# %%
df.filter(regex='present_joint_states/position', axis=1).plot(legend=False, figsize=(15, 10))

# %%
df_goal = df.filter(regex='goal_joint_states/position').columns
df_present = df.filter(regex='present_joint_states/position').columns
df_diff = pd.time
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-79-9bbe00d05610> in <module>()
#       1 df_goal = df.filter(regex='goal_joint_states/position').columns
#       2 df_present = df.filter(regex='present_joint_states/position').columns
# ----> 3 df_diff = pd.time
#
# AttributeError: module 'pandas' has no attribute 'time'

# %%
df.time
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-80-7a8b2520b58e> in <module>()
# ----> 1 df.time
#
# ~/.local/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'time'

# %%
df_diff.plot(legend=False, figsize=(15, 10))
