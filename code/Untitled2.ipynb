# %%
import rosbag_pandas as rbp
import pandas as pd
import rosbag
import math
import matplotlib.pyplot as plt
import datetime
import lz4
import numpy as np

# %%
df_err  = pd.read_csv('err_deg_p_800.csv', index_col=0)
col_names = df_err.columns
col_names = col_names + '_800'
df_err.rename(lambda x: x + '_800', axis=1)
#df_err.rename(str.join('_800'), axis='columns')
#df_err_800  = pd.read_csv('err_deg_p_900.csv')

#df_err_800  = pd.read_csv('err_deg_p_800.csv')
#df_err_900  = pd.read_csv('err_deg_p_900.csv')
#df_err_1000 = pd.read_csv('err_deg_p_1000.csv')
#df_err_1100 = pd.read_csv('err_deg_p_1100.csv')
#df_err_1200 = pd.read_csv('err_deg_p_1200.csv')
#df_err_1300 = pd.read_csv('err_deg_p_1300.csv')
# Out:
#                                      l_ankle_pitch_800  l_ankle_roll_800  \
# 2019-03-25 13:15:15.280714989+03:00                NaN               NaN
# 2019-03-25 13:15:15.280714989+03:00                NaN               NaN
# 2019-03-25 13:15:15.280714989+03:00                NaN               NaN
# 2019-03-25 13:15:15.280714989+03:00                NaN               NaN
# 2019-03-25 13:15:15.280808210+03:00                NaN               NaN
# 2019-03-25 13:15:15.280820847+03:00                NaN               NaN
# 2019-03-25 13:15:15.280833483+03:00                NaN               NaN
# 2019-03-25 13:15:15.280956745+03:00                NaN               NaN
# 2019-03-25 13:15:15.280993223+03:00                NaN               NaN
# 2019-03-25 13:15:15.281162739+03:00                NaN               NaN
# 2019-03-25 13:15:15.281188726+03:00                NaN               NaN
# 2019-03-25 13:15:15.281363249+03:00                NaN               NaN
# ...

# %%
joint_dic = {0:'l_hip_yaw',     1:'r_hip_yaw',        2:'l_hip_roll',    3:'r_hip_roll',
             4:'l_hip_pitch',   5:'r_hip_pitch',      6:'l_knee_pitch',  7:'r_knee_pitch',
             8:'l_ankle_pitch', 9:'r_ankle_pitch',   10:'l_ankle_roll', 11:'r_ankle_roll'}

df_r_hip_yaw = pd.DataFrame()
for i in range(0)
# Out:
# Empty DataFrame
# Columns: []
# Index: []
